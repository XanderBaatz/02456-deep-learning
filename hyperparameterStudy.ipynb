# %%
import numpy as np
import random
from tqdm import tqdm
import matplotlib.pyplot as plt
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch
import wandb

random.seed(27)
np.random.seed(27)
plt.style.use('ggplot')

# %% [markdown]
# # Section 1: Pilot study in subset, used to find feasible hyperparameters

# %% [markdown]
# ### Dataset - A (1/10) subset of cifar

# %% [markdown]
# We will choose a subset of the cifar10, and make sure there is class balance

# %%
# Pick dataset
ds = "cifar10"

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

if ds == "cifar10":
    train_ds = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)
    test_ds = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)

    #Normalise
    X_train = train_ds.data.astype(np.float32) / 255.0 
    y_train = np.array(train_ds.targets, dtype=np.int64)

    X_test  = test_ds.data.astype(np.float32) / 255.0
    y_test  = np.array(test_ds.targets, dtype=np.int64)

    X_train = X_train.reshape(X_train.shape[0], -1)
    X_test  = X_test.reshape(X_test.shape[0], -1)

    # Flatten
    X_train = X_train.reshape(-1, np.prod(X_train.shape[1:]))
    X_test = X_test.reshape(-1, np.prod(X_test.shape[1:]))

elif ds == "mnist":
    mnist_train = datasets.MNIST(root="./data", train=True, download=True, transform=None)
    mnist_test = datasets.MNIST(root="./data", train=False, download=True, transform=None)

    X_train = mnist_train.data.to(torch.float32).numpy()
    y_train = mnist_train.targets.to(torch.int64).numpy()

    X_test  = mnist_test.data.to(torch.float32).numpy()
    y_test  = mnist_test.targets.to(torch.int64).numpy()

    # Normalize the pixel values (important for neural nets)
    X_train /= 255.0
    X_test /= 255.0

    # Flatten
    X_train = X_train.reshape(-1, np.prod(X_train.shape[1:]))
    X_test = X_test.reshape(-1, np.prod(X_test.shape[1:]))



subset_ratio = 1/10      # take 10% of data
num_classes = 3

def balanced_subset(X, y, ratio, num_classes=2):
    X = np.array(X)
    y = np.array(y)

    indices = []
    for c in range(num_classes):
        class_idx = np.where(y == c)[0]
        n_samples = int(len(class_idx) * ratio)

        # sample without replacement
        chosen = np.random.choice(class_idx, n_samples, replace=False)
        indices.append(chosen)

    indices = np.concatenate(indices)
    np.random.shuffle(indices)

    return X[indices], y[indices]

# Apply to train + test
X_train, y_train = balanced_subset(X_train, y_train, subset_ratio, num_classes)
X_test,  y_test  = balanced_subset(X_test,  y_test,  subset_ratio, num_classes)


def one_hot_encode(y, num_classes=10):
    y_encoded = np.zeros((num_classes, y.size))
    y_encoded[y, np.arange(y.size)] = 1
    return y_encoded

Y_train = one_hot_encode(y_train, 10)  # (10, 60000)
Y_test  = one_hot_encode(y_test, 10)   # (10, 10000)

# --------------------------------------------------
# Quick check
# --------------------------------------------------
print("X_train:", X_train.shape, "Y_train:", Y_train.shape)
print("X_test: ", X_test.shape,  "Y_test: ",  Y_test.shape)
# Out:
# X_train: (1500, 3072) Y_train: (10, 1500)
# X_test:  (300, 3072) Y_test:  (10, 300)

# %% [markdown]
# ### Pilot study - we search for a feasible range of hyperparameters using sweeps

# %%
from NN.denseLayer import *
from NN.loss import *
from NN.optimizer import *

# %% [markdown]
# > Setup WANDB tracker, where we will perform a simple grid search of a VERY broad search

# %%
import matplotlib.pyplot as plt
import os
import wandb
from getAPI import retrieveApi

os.environ['WANDB_API_KEY'] = retrieveApi()

# %% [markdown]
# > Do hyperparameter sweep, on a very small subset of cifar-10

# %% [markdown]
# The code is based on the tutorials given in the sweeps documentation:
# - https://docs.wandb.ai/models/sweeps/define-sweep-configuration#python-script-or-notebook
# - https://docs.wandb.ai/models/tutorials/sweeps

# %%
sweep_configuration = {
    "method": "random",
    "metric": {"name": "loss", "goal": "minimize"},
    "parameters": {
        "learning_rate": {"distribution": "uniform", "min": 1e-6, "max": 1.0},
        "batch_size": {"values": [32, 64, 128]},
        "epochs": {"value": 30},
        "num_hidden_layers": {"distribution": "int_uniform", "min": 1, "max": 5},
        "n_hidden_units": {"distribution": "int_uniform", "min": 32, "max": 128},
        "l2_coeff": {"distribution": "uniform", "min": 0.0, "max": 0.001},
        "optimizer": {"values": ["sgd"]},
        "activation": {"values": ["relu", "tanh"]},
        "loss_fn": {"values": ["cross", "mse"]},
    },
}

sweep_id = wandb.sweep(sweep=sweep_configuration, project="numpy_nn")


def accuracy(pred, y_true):
    return (pred.argmax(axis=0) == y_true.argmax(axis=0)).mean()


def get_activation(name):
    return ReLU() if name == "relu" else Tanh()


def get_optimizer(name, lr):
    return SGD(learning_rate=lr) if name == "sgd" else Adam(learning_rate=lr)


def get_loss(name):
    return CrossEntropyLoss() if name == "cross" else MSELoss()


def build_model(input_dim, cfg):
    layers = []
    act = get_activation(cfg.activation)
    h = cfg.n_hidden_units
    prev = input_dim

    for _ in range(cfg.num_hidden_layers):
        layers.append(DenseLayer(prev, h, activation=act, initializer=HeInitializer()))
        prev = h

    layers.append(DenseLayer(prev, 10, activation=Softmax(), initializer=NormalInitializer(mean=0, std=0.01)))
    return layers

def train_run():
    wandb.init()
    cfg = wandb.config
    wandb.log(dict(cfg))

    # Build layers with L2 regularization set per layer
    layers = []
    act = get_activation(cfg.activation)
    prev = X_train.shape[1]
    h = cfg.n_hidden_units

    for _ in range(cfg.num_hidden_layers):
        layers.append(DenseLayer(prev, h, activation=act, initializer=HeInitializer(), l2_coeff=cfg.l2_coeff))
        prev = h

    layers.append(DenseLayer(prev, 10, activation=Softmax(), initializer=NormalInitializer(mean=0, std=0.01)))

    optimizer = get_optimizer(cfg.optimizer, cfg.learning_rate)
    loss_fn = get_loss(cfg.loss_fn)
    m = X_train.shape[0]

    for epoch in range(cfg.epochs):
        perm = np.random.permutation(m)
        Xs = X_train[perm].T
        Ys = Y_train[:, perm]

        for i in range(0, m, cfg.batch_size):
            Xb = Xs[:, i:i+cfg.batch_size]
            Yb = Ys[:, i:i+cfg.batch_size]

            A = Xb
            for layer in layers:
                A = layer.forward(A)

            loss = loss_fn.forward(A, Yb)
            dA = loss_fn.backward(A, Yb)

            for layer in reversed(layers):
                dA, dW, db = layer.backward(dA)
                optimizer.update(layer, dW, db)

        acc = accuracy(A, Yb)
        wandb.log({"loss": loss, "accuracy": acc})
        print(f"Epoch {epoch+1}/{cfg.epochs}  Loss={loss:.4f}  Acc={acc:.4f}")

    wandb.finish()


wandb.agent(sweep_id, function=train_run, count=10)
# Out:
# Create sweep with ID: cr5oclrk
# Sweep URL: https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk
# wandb: Agent Starting Run: wxngzj1q with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.0009612309151634822
# wandb: 	learning_rate: 0.9150623076765048
# wandb: 	loss_fn: mse
# wandb: 	n_hidden_units: 55
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103239-wxngzj1q</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/wxngzj1q' target="_blank">sparkling-sweep-1</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/wxngzj1q' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/wxngzj1q</a>
# Epoch 1/30  Loss=0.3548  Acc=0.3214
# Epoch 2/30  Loss=0.3368  Acc=0.2857
# Epoch 3/30  Loss=0.3370  Acc=0.3571
# Epoch 4/30  Loss=0.3305  Acc=0.6071
# Epoch 5/30  Loss=0.3321  Acc=0.3571
# Epoch 6/30  Loss=0.3317  Acc=0.3929
# Epoch 7/30  Loss=0.3308  Acc=0.5000
# Epoch 8/30  Loss=0.3272  Acc=0.4286
# Epoch 9/30  Loss=0.3350  Acc=0.3929
# Epoch 10/30  Loss=0.3247  Acc=0.4643
# Epoch 11/30  Loss=0.3262  Acc=0.4286
# Epoch 12/30  Loss=0.3228  Acc=0.4286
# Epoch 13/30  Loss=0.3154  Acc=0.6071
# Epoch 14/30  Loss=0.3164  Acc=0.5714
# Epoch 15/30  Loss=0.3255  Acc=0.4286
# Epoch 16/30  Loss=0.3111  Acc=0.6071
# Epoch 17/30  Loss=0.3068  Acc=0.6429
# Epoch 18/30  Loss=0.3240  Acc=0.4286
# Epoch 19/30  Loss=0.3138  Acc=0.4643
# Epoch 20/30  Loss=0.3088  Acc=0.5357
# Epoch 21/30  Loss=0.3260  Acc=0.4286
# Epoch 22/30  Loss=0.3251  Acc=0.4286
# Epoch 23/30  Loss=0.3146  Acc=0.3929
# Epoch 24/30  Loss=0.3071  Acc=0.4643
# Epoch 25/30  Loss=0.3005  Acc=0.5357
# Epoch 26/30  Loss=0.2846  Acc=0.6071
# Epoch 27/30  Loss=0.2891  Acc=0.5714
# Epoch 28/30  Loss=0.2883  Acc=0.5714
# Epoch 29/30  Loss=0.3145  Acc=0.3929
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 30/30  Loss=0.2931  Acc=0.5357
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▂▁▂▇▂▃▅▄▃▄▄▄▇▇▄▇█▄▄▆▄▄▃▄▆▇▇▇▃▆</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>loss</td><td>█▆▆▆▆▆▆▅▆▅▅▅▄▄▅▄▃▅▄▃▅▅▄▃▃▁▁▁▄▂</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.53571</td></tr><tr><td>activation</td><td>tanh</td></tr><tr><td>batch_size</td><td>64</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00096</td></tr><tr><td>learning_rate</td><td>0.91506</td></tr><tr><td>loss</td><td>0.2931</td></tr><tr><td>loss_fn</td><td>mse</td></tr><tr><td>n_hidden_units</td><td>55</td></tr><tr><td>num_hidden_layers</td><td>5</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sparkling-sweep-1</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/wxngzj1q' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/wxngzj1q</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103239-wxngzj1q/logs</code>
# wandb: Agent Starting Run: yzzi0kmi with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.0006441350926703784
# wandb: 	learning_rate: 0.9681327816564806
# wandb: 	loss_fn: cross
# wandb: 	n_hidden_units: 106
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103250-yzzi0kmi</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/yzzi0kmi' target="_blank">deft-sweep-2</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/yzzi0kmi' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/yzzi0kmi</a>
# Epoch 1/30  Loss=1.2923  Acc=0.3571
# Epoch 2/30  Loss=1.1581  Acc=0.3929
# Epoch 3/30  Loss=1.1475  Acc=0.3214
# Epoch 4/30  Loss=1.1300  Acc=0.3571
# Epoch 5/30  Loss=1.1355  Acc=0.1071
# Epoch 6/30  Loss=1.1198  Acc=0.3571
# Epoch 7/30  Loss=1.1064  Acc=0.4286
# Epoch 8/30  Loss=1.1118  Acc=0.3214
# Epoch 9/30  Loss=1.1093  Acc=0.2500
# Epoch 10/30  Loss=1.0965  Acc=0.3929
# Epoch 11/30  Loss=1.1102  Acc=0.2857
# Epoch 12/30  Loss=1.0945  Acc=0.4643
# Epoch 13/30  Loss=1.1067  Acc=0.3214
# Epoch 14/30  Loss=1.0966  Acc=0.3929
# Epoch 15/30  Loss=1.0922  Acc=0.4643
# Epoch 16/30  Loss=1.1243  Acc=0.2857
# Epoch 17/30  Loss=1.1108  Acc=0.2143
# Epoch 18/30  Loss=1.1031  Acc=0.3214
# Epoch 19/30  Loss=1.1043  Acc=0.3571
# Epoch 20/30  Loss=1.1042  Acc=0.3214
# Epoch 21/30  Loss=1.1004  Acc=0.3571
# Epoch 22/30  Loss=1.1075  Acc=0.2857
# Epoch 23/30  Loss=1.1228  Acc=0.1786
# Epoch 24/30  Loss=1.0915  Acc=0.4643
# Epoch 25/30  Loss=1.1051  Acc=0.2500
# Epoch 26/30  Loss=1.0947  Acc=0.3929
# Epoch 27/30  Loss=1.1074  Acc=0.2857
# Epoch 28/30  Loss=1.1186  Acc=0.2500
# Epoch 29/30  Loss=1.1018  Acc=0.3929
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 30/30  Loss=1.0948  Acc=0.3214
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▆▇▅▆▁▆▇▅▄▇▅█▅▇█▅▃▅▆▅▆▅▂█▄▇▅▄▇▅</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>loss</td><td>█▃▃▂▃▂▂▂▂▁▂▁▂▁▁▂▂▁▁▁▁▂▂▁▁▁▂▂▁▁</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.32143</td></tr><tr><td>activation</td><td>relu</td></tr><tr><td>batch_size</td><td>64</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00064</td></tr><tr><td>learning_rate</td><td>0.96813</td></tr><tr><td>loss</td><td>1.09476</td></tr><tr><td>loss_fn</td><td>cross</td></tr><tr><td>n_hidden_units</td><td>106</td></tr><tr><td>num_hidden_layers</td><td>2</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">deft-sweep-2</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/yzzi0kmi' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/yzzi0kmi</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103250-yzzi0kmi/logs</code>
# wandb: Agent Starting Run: z4g7ed3l with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.0005365751631820697
# wandb: 	learning_rate: 0.30010208785908193
# wandb: 	loss_fn: cross
# wandb: 	n_hidden_units: 78
# wandb: 	num_hidden_layers: 4
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103301-z4g7ed3l</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/z4g7ed3l' target="_blank">rural-sweep-3</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/z4g7ed3l' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/z4g7ed3l</a>
# /workspaces/02456-deep-learning/NN/activations.py:48: RuntimeWarning: invalid value encountered in subtract
#   exp_Z = np.exp(Z - np.max(Z, axis=0, keepdims=True))
# Epoch 1/30  Loss=nan  Acc=0.3043
# Epoch 2/30  Loss=nan  Acc=0.3261
# Epoch 3/30  Loss=nan  Acc=0.3696
# Epoch 4/30  Loss=nan  Acc=0.3370
# Epoch 5/30  Loss=nan  Acc=0.3370
# Epoch 6/30  Loss=nan  Acc=0.3152
# Epoch 7/30  Loss=nan  Acc=0.2500
# Epoch 8/30  Loss=nan  Acc=0.3478
# Epoch 9/30  Loss=nan  Acc=0.3478
# Epoch 10/30  Loss=nan  Acc=0.3804
# Epoch 11/30  Loss=nan  Acc=0.3913
# Epoch 12/30  Loss=nan  Acc=0.3152
# Epoch 13/30  Loss=nan  Acc=0.3261
# Epoch 14/30  Loss=nan  Acc=0.3587
# Epoch 15/30  Loss=nan  Acc=0.3152
# Epoch 16/30  Loss=nan  Acc=0.2609
# Epoch 17/30  Loss=nan  Acc=0.3152
# Epoch 18/30  Loss=nan  Acc=0.3152
# Epoch 19/30  Loss=nan  Acc=0.3478
# Epoch 20/30  Loss=nan  Acc=0.2609
# Epoch 21/30  Loss=nan  Acc=0.3478
# Epoch 22/30  Loss=nan  Acc=0.3370
# Epoch 23/30  Loss=nan  Acc=0.3370
# Epoch 24/30  Loss=nan  Acc=0.3152
# Epoch 25/30  Loss=nan  Acc=0.3043
# Epoch 26/30  Loss=nan  Acc=0.3913
# Epoch 27/30  Loss=nan  Acc=0.3043
# Epoch 28/30  Loss=nan  Acc=0.3478
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 29/30  Loss=nan  Acc=0.2826
# Epoch 30/30  Loss=nan  Acc=0.3696
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▄▅▇▅▅▄▁▆▆▇█▄▅▆▄▂▄▄▆▂▆▅▅▄▄█▄▆▃▇</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.36957</td></tr><tr><td>activation</td><td>relu</td></tr><tr><td>batch_size</td><td>128</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00054</td></tr><tr><td>learning_rate</td><td>0.3001</td></tr><tr><td>loss</td><td>nan</td></tr><tr><td>loss_fn</td><td>cross</td></tr><tr><td>n_hidden_units</td><td>78</td></tr><tr><td>num_hidden_layers</td><td>4</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rural-sweep-3</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/z4g7ed3l' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/z4g7ed3l</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103301-z4g7ed3l/logs</code>
# wandb: Agent Starting Run: odi8juml with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.0007703105926588215
# wandb: 	learning_rate: 0.582419387297521
# wandb: 	loss_fn: cross
# wandb: 	n_hidden_units: 45
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103312-odi8juml</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/odi8juml' target="_blank">driven-sweep-4</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/odi8juml' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/odi8juml</a>
# /workspaces/02456-deep-learning/NN/activations.py:48: RuntimeWarning: invalid value encountered in subtract
#   exp_Z = np.exp(Z - np.max(Z, axis=0, keepdims=True))
# Epoch 1/30  Loss=nan  Acc=0.3214
# Epoch 2/30  Loss=nan  Acc=0.2857
# Epoch 3/30  Loss=nan  Acc=0.3929
# Epoch 4/30  Loss=nan  Acc=0.3214
# Epoch 5/30  Loss=nan  Acc=0.2857
# Epoch 6/30  Loss=nan  Acc=0.5000
# Epoch 7/30  Loss=nan  Acc=0.4286
# Epoch 8/30  Loss=nan  Acc=0.1786
# Epoch 9/30  Loss=nan  Acc=0.2857
# Epoch 10/30  Loss=nan  Acc=0.2500
# Epoch 11/30  Loss=nan  Acc=0.2500
# Epoch 12/30  Loss=nan  Acc=0.4286
# Epoch 13/30  Loss=nan  Acc=0.3214
# Epoch 14/30  Loss=nan  Acc=0.3571
# Epoch 15/30  Loss=nan  Acc=0.2857
# Epoch 16/30  Loss=nan  Acc=0.3214
# Epoch 17/30  Loss=nan  Acc=0.2143
# Epoch 18/30  Loss=nan  Acc=0.3571
# Epoch 19/30  Loss=nan  Acc=0.2143
# Epoch 20/30  Loss=nan  Acc=0.3571
# Epoch 21/30  Loss=nan  Acc=0.3929
# Epoch 22/30  Loss=nan  Acc=0.3929
# Epoch 23/30  Loss=nan  Acc=0.2857
# Epoch 24/30  Loss=nan  Acc=0.3214
# Epoch 25/30  Loss=nan  Acc=0.1786
# Epoch 26/30  Loss=nan  Acc=0.4286
# Epoch 27/30  Loss=nan  Acc=0.3929
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 28/30  Loss=nan  Acc=0.3571
# Epoch 29/30  Loss=nan  Acc=0.3571
# Epoch 30/30  Loss=nan  Acc=0.3571
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▄▃▆▄▃█▆▁▃▃▃▆▄▅▃▄▂▅▂▅▆▆▃▄▁▆▆▅▅▅</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.35714</td></tr><tr><td>activation</td><td>relu</td></tr><tr><td>batch_size</td><td>32</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00077</td></tr><tr><td>learning_rate</td><td>0.58242</td></tr><tr><td>loss</td><td>nan</td></tr><tr><td>loss_fn</td><td>cross</td></tr><tr><td>n_hidden_units</td><td>45</td></tr><tr><td>num_hidden_layers</td><td>3</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">driven-sweep-4</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/odi8juml' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/odi8juml</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103312-odi8juml/logs</code>
# wandb: Agent Starting Run: ejt6jugu with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 128
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.0003054350522506906
# wandb: 	learning_rate: 0.2132057620430853
# wandb: 	loss_fn: cross
# wandb: 	n_hidden_units: 98
# wandb: 	num_hidden_layers: 4
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103322-ejt6jugu</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/ejt6jugu' target="_blank">golden-sweep-5</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/ejt6jugu' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/ejt6jugu</a>
# Epoch 1/30  Loss=1.5477  Acc=0.3043
# Epoch 2/30  Loss=1.1390  Acc=0.3152
# Epoch 3/30  Loss=1.3167  Acc=0.4239
# Epoch 4/30  Loss=1.3679  Acc=0.3261
# Epoch 5/30  Loss=1.8564  Acc=0.3478
# Epoch 6/30  Loss=1.4271  Acc=0.3587
# Epoch 7/30  Loss=1.1645  Acc=0.3370
# Epoch 8/30  Loss=1.3134  Acc=0.3370
# Epoch 9/30  Loss=1.1801  Acc=0.2391
# Epoch 10/30  Loss=1.4073  Acc=0.4239
# Epoch 11/30  Loss=1.1293  Acc=0.4457
# Epoch 12/30  Loss=1.3694  Acc=0.3043
# Epoch 13/30  Loss=1.3509  Acc=0.4348
# Epoch 14/30  Loss=1.1939  Acc=0.3696
# Epoch 15/30  Loss=1.0722  Acc=0.3370
# Epoch 16/30  Loss=1.1666  Acc=0.4130
# Epoch 17/30  Loss=1.3189  Acc=0.4674
# Epoch 18/30  Loss=1.6932  Acc=0.3152
# Epoch 19/30  Loss=1.3358  Acc=0.5326
# Epoch 20/30  Loss=1.1098  Acc=0.4783
# Epoch 21/30  Loss=1.0010  Acc=0.4891
# Epoch 22/30  Loss=1.1017  Acc=0.4674
# Epoch 23/30  Loss=1.2203  Acc=0.5217
# Epoch 24/30  Loss=1.0197  Acc=0.4457
# Epoch 25/30  Loss=1.0201  Acc=0.5109
# Epoch 26/30  Loss=1.1461  Acc=0.4130
# Epoch 27/30  Loss=1.0263  Acc=0.5217
# Epoch 28/30  Loss=0.9204  Acc=0.5543
# Epoch 29/30  Loss=0.8809  Acc=0.5761
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 30/30  Loss=0.8923  Acc=0.5978
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▂▂▅▃▃▃▃▃▁▅▅▂▅▄▃▄▅▂▇▆▆▅▇▅▆▄▇▇██</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>loss</td><td>▆▃▄▄█▅▃▄▃▅▃▅▄▃▂▃▄▇▄▃▂▃▃▂▂▃▂▁▁▁</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.59783</td></tr><tr><td>activation</td><td>tanh</td></tr><tr><td>batch_size</td><td>128</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00031</td></tr><tr><td>learning_rate</td><td>0.21321</td></tr><tr><td>loss</td><td>0.89228</td></tr><tr><td>loss_fn</td><td>cross</td></tr><tr><td>n_hidden_units</td><td>98</td></tr><tr><td>num_hidden_layers</td><td>4</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">golden-sweep-5</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/ejt6jugu' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/ejt6jugu</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103322-ejt6jugu/logs</code>
# wandb: Agent Starting Run: 38lavwu0 with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 128
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.0009435276065790288
# wandb: 	learning_rate: 0.6507824825970303
# wandb: 	loss_fn: cross
# wandb: 	n_hidden_units: 102
# wandb: 	num_hidden_layers: 1
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103333-38lavwu0</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/38lavwu0' target="_blank">good-sweep-6</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/38lavwu0' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/38lavwu0</a>
# Epoch 1/30  Loss=8.1739  Acc=0.3587
# Epoch 2/30  Loss=7.4175  Acc=0.4239
# Epoch 3/30  Loss=10.0106  Acc=0.3913
# Epoch 4/30  Loss=13.6124  Acc=0.2609
# Epoch 5/30  Loss=10.2875  Acc=0.3804
# Epoch 6/30  Loss=14.2158  Acc=0.2283
# Epoch 7/30  Loss=7.7113  Acc=0.3696
# Epoch 8/30  Loss=10.2328  Acc=0.3370
# Epoch 9/30  Loss=8.6454  Acc=0.3696
# Epoch 10/30  Loss=10.3135  Acc=0.3370
# Epoch 11/30  Loss=12.8144  Acc=0.3043
# Epoch 12/30  Loss=9.8109  Acc=0.4674
# Epoch 13/30  Loss=12.2137  Acc=0.3370
# Epoch 14/30  Loss=11.8133  Acc=0.3587
# Epoch 15/30  Loss=12.0135  Acc=0.3478
# Epoch 16/30  Loss=8.1793  Acc=0.3043
# Epoch 17/30  Loss=11.9627  Acc=0.3478
# Epoch 18/30  Loss=9.0385  Acc=0.3478
# Epoch 19/30  Loss=11.2885  Acc=0.2826
# Epoch 20/30  Loss=10.1558  Acc=0.3261
# Epoch 21/30  Loss=12.0135  Acc=0.3478
# Epoch 22/30  Loss=14.2160  Acc=0.2283
# Epoch 23/30  Loss=11.3369  Acc=0.3696
# Epoch 24/30  Loss=10.7155  Acc=0.3913
# Epoch 25/30  Loss=13.2148  Acc=0.2826
# Epoch 26/30  Loss=10.0765  Acc=0.3913
# Epoch 27/30  Loss=12.4043  Acc=0.3261
# Epoch 28/30  Loss=12.5181  Acc=0.3152
# Epoch 29/30  Loss=13.2148  Acc=0.2826
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 30/30  Loss=6.7304  Acc=0.2717
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▅▇▆▂▅▁▅▄▅▄▃█▄▅▅▃▅▅▃▄▅▁▅▆▃▆▄▄▃▂</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>loss</td><td>▂▂▄▇▄█▂▄▃▄▇▄▆▆▆▂▆▃▅▄▆█▅▅▇▄▆▆▇▁</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.27174</td></tr><tr><td>activation</td><td>tanh</td></tr><tr><td>batch_size</td><td>128</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00094</td></tr><tr><td>learning_rate</td><td>0.65078</td></tr><tr><td>loss</td><td>6.73036</td></tr><tr><td>loss_fn</td><td>cross</td></tr><tr><td>n_hidden_units</td><td>102</td></tr><tr><td>num_hidden_layers</td><td>1</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">good-sweep-6</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/38lavwu0' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/38lavwu0</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103333-38lavwu0/logs</code>
# wandb: Agent Starting Run: efay0ef7 with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.0008503490011638776
# wandb: 	learning_rate: 0.02819260386997762
# wandb: 	loss_fn: mse
# wandb: 	n_hidden_units: 118
# wandb: 	num_hidden_layers: 5
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103344-efay0ef7</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/efay0ef7' target="_blank">young-sweep-7</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/efay0ef7' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/efay0ef7</a>
# Epoch 1/30  Loss=0.4479  Acc=0.1087
# Epoch 2/30  Loss=0.4473  Acc=0.1739
# Epoch 3/30  Loss=0.4462  Acc=0.2391
# Epoch 4/30  Loss=0.4449  Acc=0.4239
# Epoch 5/30  Loss=0.4453  Acc=0.3043
# Epoch 6/30  Loss=0.4438  Acc=0.3370
# Epoch 7/30  Loss=0.4423  Acc=0.3587
# Epoch 8/30  Loss=0.4412  Acc=0.4674
# Epoch 9/30  Loss=0.4399  Acc=0.4348
# Epoch 10/30  Loss=0.4399  Acc=0.3587
# Epoch 11/30  Loss=0.4393  Acc=0.2609
# Epoch 12/30  Loss=0.4369  Acc=0.4565
# Epoch 13/30  Loss=0.4372  Acc=0.3587
# Epoch 14/30  Loss=0.4361  Acc=0.3261
# Epoch 15/30  Loss=0.4360  Acc=0.3478
# Epoch 16/30  Loss=0.4344  Acc=0.2609
# Epoch 17/30  Loss=0.4332  Acc=0.3152
# Epoch 18/30  Loss=0.4319  Acc=0.3587
# Epoch 19/30  Loss=0.4316  Acc=0.3261
# Epoch 20/30  Loss=0.4298  Acc=0.4239
# Epoch 21/30  Loss=0.4291  Acc=0.3478
# Epoch 22/30  Loss=0.4265  Acc=0.3804
# Epoch 23/30  Loss=0.4281  Acc=0.2717
# Epoch 24/30  Loss=0.4252  Acc=0.3478
# Epoch 25/30  Loss=0.4247  Acc=0.3478
# Epoch 26/30  Loss=0.4218  Acc=0.3804
# Epoch 27/30  Loss=0.4211  Acc=0.3587
# Epoch 28/30  Loss=0.4199  Acc=0.4239
# Epoch 29/30  Loss=0.4174  Acc=0.4022
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 30/30  Loss=0.4183  Acc=0.3696
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▄▇▅▅▆█▇▆▄█▆▅▆▄▅▆▅▇▆▆▄▆▆▆▆▇▇▆</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>loss</td><td>███▇▇▇▇▆▆▆▆▅▆▅▅▅▅▄▄▄▄▃▃▃▃▂▂▂▁▁</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.36957</td></tr><tr><td>activation</td><td>relu</td></tr><tr><td>batch_size</td><td>128</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00085</td></tr><tr><td>learning_rate</td><td>0.02819</td></tr><tr><td>loss</td><td>0.41827</td></tr><tr><td>loss_fn</td><td>mse</td></tr><tr><td>n_hidden_units</td><td>118</td></tr><tr><td>num_hidden_layers</td><td>5</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">young-sweep-7</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/efay0ef7' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/efay0ef7</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103344-efay0ef7/logs</code>
# wandb: Agent Starting Run: 410dvf6m with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.0004939282348011701
# wandb: 	learning_rate: 0.822300294896828
# wandb: 	loss_fn: cross
# wandb: 	n_hidden_units: 91
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103354-410dvf6m</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/410dvf6m' target="_blank">peach-sweep-8</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/410dvf6m' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/410dvf6m</a>
# Epoch 1/30  Loss=1.2051  Acc=0.2857
# Epoch 2/30  Loss=1.1522  Acc=0.2500
# Epoch 3/30  Loss=1.1364  Acc=0.3571
# Epoch 4/30  Loss=1.1135  Acc=0.3214
# Epoch 5/30  Loss=1.1293  Acc=0.2857
# Epoch 6/30  Loss=1.0807  Acc=0.5000
# Epoch 7/30  Loss=1.1010  Acc=0.3214
# Epoch 8/30  Loss=1.1062  Acc=0.3571
# Epoch 9/30  Loss=1.0549  Acc=0.4643
# Epoch 10/30  Loss=1.1146  Acc=0.2857
# Epoch 11/30  Loss=1.1023  Acc=0.3929
# Epoch 12/30  Loss=1.0725  Acc=0.4286
# Epoch 13/30  Loss=1.0927  Acc=0.4286
# Epoch 14/30  Loss=1.1008  Acc=0.3929
# Epoch 15/30  Loss=1.0925  Acc=0.4286
# Epoch 16/30  Loss=1.1172  Acc=0.3214
# Epoch 17/30  Loss=1.1250  Acc=0.2857
# Epoch 18/30  Loss=1.1050  Acc=0.2500
# Epoch 19/30  Loss=1.1039  Acc=0.3929
# Epoch 20/30  Loss=1.1025  Acc=0.1786
# Epoch 21/30  Loss=1.0987  Acc=0.3929
# Epoch 22/30  Loss=1.0988  Acc=0.4286
# Epoch 23/30  Loss=1.1066  Acc=0.3214
# Epoch 24/30  Loss=1.1929  Acc=0.0714
# Epoch 25/30  Loss=1.0974  Acc=0.2500
# Epoch 26/30  Loss=1.0970  Acc=0.3929
# Epoch 27/30  Loss=1.1269  Acc=0.2857
# Epoch 28/30  Loss=1.0792  Acc=0.4286
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 29/30  Loss=1.1394  Acc=0.1786
# Epoch 30/30  Loss=1.0975  Acc=0.3214
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▅▄▆▅▅█▅▆▇▅▆▇▇▆▇▅▅▄▆▃▆▇▅▁▄▆▅▇▃▅</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>loss</td><td>█▆▅▄▄▂▃▃▁▄▃▂▃▃▃▄▄▃▃▃▃▃▃▇▃▃▄▂▅▃</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.32143</td></tr><tr><td>activation</td><td>relu</td></tr><tr><td>batch_size</td><td>32</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00049</td></tr><tr><td>learning_rate</td><td>0.8223</td></tr><tr><td>loss</td><td>1.09746</td></tr><tr><td>loss_fn</td><td>cross</td></tr><tr><td>n_hidden_units</td><td>91</td></tr><tr><td>num_hidden_layers</td><td>2</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peach-sweep-8</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/410dvf6m' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/410dvf6m</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103354-410dvf6m/logs</code>
# wandb: Agent Starting Run: h6d9rs3v with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 0.00040930048308229495
# wandb: 	learning_rate: 0.698183501079988
# wandb: 	loss_fn: mse
# wandb: 	n_hidden_units: 98
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103405-h6d9rs3v</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/h6d9rs3v' target="_blank">exalted-sweep-9</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/h6d9rs3v' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/h6d9rs3v</a>
# Epoch 1/30  Loss=0.3434  Acc=0.3929
# Epoch 2/30  Loss=0.3240  Acc=0.5714
# Epoch 3/30  Loss=0.3341  Acc=0.2857
# Epoch 4/30  Loss=0.3249  Acc=0.4286
# Epoch 5/30  Loss=0.3244  Acc=0.4286
# Epoch 6/30  Loss=0.3214  Acc=0.5000
# Epoch 7/30  Loss=0.3171  Acc=0.4643
# Epoch 8/30  Loss=0.3227  Acc=0.3571
# Epoch 9/30  Loss=0.3125  Acc=0.4286
# Epoch 10/30  Loss=0.2948  Acc=0.6071
# Epoch 11/30  Loss=0.3153  Acc=0.5714
# Epoch 12/30  Loss=0.3142  Acc=0.3214
# Epoch 13/30  Loss=0.2894  Acc=0.5357
# Epoch 14/30  Loss=0.2984  Acc=0.5357
# Epoch 15/30  Loss=0.2941  Acc=0.6071
# Epoch 16/30  Loss=0.2448  Acc=0.7143
# Epoch 17/30  Loss=0.2790  Acc=0.5000
# Epoch 18/30  Loss=0.3000  Acc=0.5357
# Epoch 19/30  Loss=0.2887  Acc=0.5357
# Epoch 20/30  Loss=0.2932  Acc=0.6071
# Epoch 21/30  Loss=0.2833  Acc=0.6429
# Epoch 22/30  Loss=0.2264  Acc=0.7500
# Epoch 23/30  Loss=0.2252  Acc=0.7500
# Epoch 24/30  Loss=0.2308  Acc=0.6786
# Epoch 25/30  Loss=0.2525  Acc=0.6786
# Epoch 26/30  Loss=0.2430  Acc=0.6786
# Epoch 27/30  Loss=0.2928  Acc=0.4643
# Epoch 28/30  Loss=0.2347  Acc=0.7143
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 29/30  Loss=0.2576  Acc=0.7143
# Epoch 30/30  Loss=0.2230  Acc=0.7500
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▃▅▁▃▃▄▄▂▃▆▅▂▅▅▆▇▄▅▅▆▆██▇▇▇▄▇▇█</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>loss</td><td>█▇▇▇▇▇▆▇▆▅▆▆▅▅▅▂▄▅▅▅▅▁▁▁▃▂▅▂▃▁</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.75</td></tr><tr><td>activation</td><td>tanh</td></tr><tr><td>batch_size</td><td>64</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>0.00041</td></tr><tr><td>learning_rate</td><td>0.69818</td></tr><tr><td>loss</td><td>0.22303</td></tr><tr><td>loss_fn</td><td>mse</td></tr><tr><td>n_hidden_units</td><td>98</td></tr><tr><td>num_hidden_layers</td><td>2</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exalted-sweep-9</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/h6d9rs3v' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/h6d9rs3v</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103405-h6d9rs3v/logs</code>
# wandb: Agent Starting Run: 6xqkl2u1 with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 30
# wandb: 	l2_coeff: 4.4390556586005326e-05
# wandb: 	learning_rate: 0.0026995599295566663
# wandb: 	loss_fn: mse
# wandb: 	n_hidden_units: 99
# wandb: 	num_hidden_layers: 1
# wandb: 	optimizer: sgd
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/workspaces/02456-deep-learning/wandb/run-20251124_103415-6xqkl2u1</code>
# Syncing run <strong><a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/6xqkl2u1' target="_blank">zesty-sweep-10</a></strong> to <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View project at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a>
#  View sweep at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/sweeps/cr5oclrk</a>
#  View run at <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/6xqkl2u1' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/6xqkl2u1</a>
# Epoch 1/30  Loss=0.4511  Acc=0.3214
# Epoch 2/30  Loss=0.4504  Acc=0.3214
# Epoch 3/30  Loss=0.4465  Acc=0.1786
# Epoch 4/30  Loss=0.4452  Acc=0.3571
# Epoch 5/30  Loss=0.4463  Acc=0.3571
# Epoch 6/30  Loss=0.4438  Acc=0.3214
# Epoch 7/30  Loss=0.4440  Acc=0.2500
# Epoch 8/30  Loss=0.4416  Acc=0.3929
# Epoch 9/30  Loss=0.4478  Acc=0.0357
# Epoch 10/30  Loss=0.4418  Acc=0.3571
# Epoch 11/30  Loss=0.4441  Acc=0.1786
# Epoch 12/30  Loss=0.4416  Acc=0.3214
# Epoch 13/30  Loss=0.4430  Acc=0.1429
# Epoch 14/30  Loss=0.4392  Acc=0.2143
# Epoch 15/30  Loss=0.4366  Acc=0.3571
# Epoch 16/30  Loss=0.4375  Acc=0.3214
# Epoch 17/30  Loss=0.4372  Acc=0.3929
# Epoch 18/30  Loss=0.4327  Acc=0.4286
# Epoch 19/30  Loss=0.4313  Acc=0.6071
# Epoch 20/30  Loss=0.4293  Acc=0.4286
# Epoch 21/30  Loss=0.4316  Acc=0.3571
# Epoch 22/30  Loss=0.4360  Acc=0.2143
# Epoch 23/30  Loss=0.4361  Acc=0.1786
# Epoch 24/30  Loss=0.4294  Acc=0.3214
# Epoch 25/30  Loss=0.4271  Acc=0.3571
# Epoch 26/30  Loss=0.4292  Acc=0.3571
# Epoch 27/30  Loss=0.4297  Acc=0.2143
# Epoch 28/30  Loss=0.4267  Acc=0.3929
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Epoch 29/30  Loss=0.4271  Acc=0.2857
# Epoch 30/30  Loss=0.4242  Acc=0.3929
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▄▄▃▅▅▄▄▅▁▅▃▄▂▃▅▄▅▆█▆▅▃▃▄▅▅▃▅▄▅</td></tr><tr><td>batch_size</td><td>▁</td></tr><tr><td>epochs</td><td>▁</td></tr><tr><td>l2_coeff</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>loss</td><td>██▇▆▇▆▆▆▇▆▆▆▆▅▄▄▄▃▃▂▃▄▄▂▂▂▂▂▂▁</td></tr><tr><td>n_hidden_units</td><td>▁</td></tr><tr><td>num_hidden_layers</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.39286</td></tr><tr><td>activation</td><td>relu</td></tr><tr><td>batch_size</td><td>64</td></tr><tr><td>epochs</td><td>30</td></tr><tr><td>l2_coeff</td><td>4e-05</td></tr><tr><td>learning_rate</td><td>0.0027</td></tr><tr><td>loss</td><td>0.42415</td></tr><tr><td>loss_fn</td><td>mse</td></tr><tr><td>n_hidden_units</td><td>99</td></tr><tr><td>num_hidden_layers</td><td>1</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">zesty-sweep-10</strong> at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/6xqkl2u1' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn/runs/6xqkl2u1</a><br> View project at: <a href='https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn' target="_blank">https://wandb.ai/xanderbaatz-danmarks-tekniske-universitet-dtu/numpy_nn</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251124_103415-6xqkl2u1/logs</code>

# %% [markdown]
# # Section 2: Hyperparameter study using grid search, random search and bayesian optimization

# %% [markdown]
# # Section 3: Validation of model
